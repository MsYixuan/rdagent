# %%
from rdagent.cloudgpt_aoai import get_chat_completion

def chat_with_gpt():
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is 2+2?"}
    ]
    
    response = get_chat_completion(
        messages=messages,
        model="gpt-4o-20241120",
        temperature=0.7,
        max_tokens=200
    )
    
    return response.choices[0].message.content

if __name__ == "__main__":
    result = chat_with_gpt()
    print(result)
# Out:
# 2 + 2 equals 4.

# %%
from rdagent.cloudgpt_aoai import get_openai_token_provider

def test_token_provider():
    token_provider = get_openai_token_provider()
    token = token_provider()
    print(f"Retrieved token: {token}")

if __name__ == "__main__":

    result = test_token_provider()
    print(result)
# Out:
# Retrieved token: eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IlFaZ045SHFOa0dORU00R2VLY3pEMDJQY1Z2NCIsImtpZCI6IlFaZ045SHFOa0dORU00R2VLY3pEMDJQY1Z2NCJ9.....Q6vQoLs0LiHUKqa3Ilnee4N1k9GdTkzttp7nfhW1me9Oxw9XyyIiUkwljX_4HSIpqqRZXyAE3FttpsIcIPoANBHE6cbkgLyimRUO85u2SFo44StT2ry2I5xfRYeXgQE7fZTbfsj0v_2qBVHZJdftxF-rLtoXCGXUskbuTVtmI5Q_12YY-0Ic8x9fhRcGSlFUw-WoXNZZHCFxryNbOoLfYa8X4fl3Wfe9VIf8LO6sTZcSSAqTD9Z-utVyFzXgwkc5fA-9EV0t5JLvWYoIaihvSTdvuPkgZP4LS5kyde3NDDuWfpXRXEcmh_QBYKm5hmvvTydHlqqhTP-dZRYO2f0ayQ
# None

# %%
from rdagent.cloudgpt_aoai import get_openai_client

def test_openai_client():
    client = get_openai_client()
    # print(client)
    response = client.chat.completions.create(
        model="gpt-4o-20241120",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": "What is the capital of France?"}
        ],
        temperature=0.7,
        max_tokens=200
    )
    print(f"Response: {response.choices[0].message.content}")
